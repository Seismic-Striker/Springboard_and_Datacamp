# %% [markdown]
# # Using Counter on lists
# Counter is a powerful tool for counting, validating, and learning more about the elements within a dataset that is found in the collections module. You pass an iterable (list, set, tuple) or a dictionary to the Counter. You can also use the Counter object similarly to a dictionary with key/value assignment, for example counter[key] = value.
#
# A common usage for Counter is checking data for consistency prior to using it, so let's do just that. In this exercise, you'll be using data from the Chicago Transit Authority on ridership.
#
# Instructions
# 100 XP
# Import the Counter object from collections.
# Print the first ten items from the stations list.
# Create a Counter of the stations list called station_count.
# Print the station_count.

# %%
from collections import Counter
new_counter = Counter(data)
.most_commom(3)#for top3
# Out:
#   File "<ipython-input-1-a805f1ede766>", line 3
#     .most_commom(3)#for top3
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Using Counter on lists
# Counter is a powerful tool for counting, validating, and learning more about the elements within a dataset that is found in the collections module. You pass an iterable (list, set, tuple) or a dictionary to the Counter. You can also use the Counter object similarly to a dictionary with key/value assignment, for example counter[key] = value.
#
# A common usage for Counter is checking data for consistency prior to using it, so let's do just that. In this exercise, you'll be using data from the Chicago Transit Authority on ridership.
#
# Instructions
# 100 XP
# Import the Counter object from collections.
# Print the first ten items from the stations list.
# Create a Counter of the stations list called station_count.
# Print the station_count.

# %%
stations = ['stationname', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'LaSalle', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place']


# Import the Counter object
from collections import Counter

# Print the first ten items from the stations list
print(stations[:10])

# Create a Counter of the stations list: station_count
station_count = Counter(stations)

# Print the station_count
print(station_count)

statprint(station_count.most_common(5))
# Out:
# ['stationname', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park']
# ...

# %% [markdown]
# # Finding most common elements
# Another powerful usage of Counter is finding the most common elements in a list. This can be done with the .most_common() method.
#
# Practice using this now to find the most common stations in a stations list.
#
# Instructions
# 100 XP
# Import the Counter object from collections.
# Create a Counter of the stations list called station_count.
# Print the 5 most common elements.

# %%
stations=['stationname', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Austin-Forest Park', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Harlem-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Pulaski-Lake', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Quincy/Wells', 'Davis', 'Davis', 'Davis', 'Davis', "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", "Belmont-O'Hare", 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Jackson/Dearborn', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Sheridan', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Damen-Brown', 'Morse', 'Morse', 'Morse', 'Morse', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '35th/Archer', '51st', '51st', '51st', '51st', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Dempster-Skokie', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'Pulaski-Cermak', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'LaSalle/Van Buren', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Ashland-Lake', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Oak Park-Forest Park', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Sox-35th-Dan Ryan', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Randolph/Wabash', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Damen-Cermak', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Western-Forest Park', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', 'Cumberland', '79th', '79th', '79th', '79th', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'Kedzie-Homan-Forest Park', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'State/Lake', 'Main', 'Main', 'Main', 'Main', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Central-Lake', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Ashland/63rd', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Indiana', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Western-Orange', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Division/Milwaukee', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Grand/State', 'Berwyn', 'Berwyn', 'Berwyn', 'Berwyn', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'UIC-Halsted', 'Southport', 'Southport', 'Southport', 'Southport', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Washington/Dearborn', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Clark/Lake', 'Forest Park', 'Forest Park', 'Forest Park', 'Forest Park', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Noyes', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Cicero-Cermak', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'Clinton-Forest Park', 'California-Cermak', 'California-Cermak', 'California-Cermak', 'California-Cermak', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', '95th/Dan Ryan', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Merchandise Mart', 'Racine', 'Racine', 'Racine', 'Racine', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Cicero-Lake', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Grand/Milwaukee', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Garfield-South Elevated', 'Foster', 'Foster', 'Foster', 'Foster', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Diversey', 'Wilson', 'Wilson', 'Wilson', 'Wilson', "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", "Irving Park-O'Hare", 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'Jackson/State', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', 'California/Milwaukee', '54th/Cermak', '54th/Cermak', '54th/Cermak', '54th/Cermak', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Damen/Milwaukee', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Kostner', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Ridgeland', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Clark/Division', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'Madison/Wabash', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'North/Clybourn', 'Armitage', 'Armitage', 'Armitage', 'Armitage', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Western/Milwaukee', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Adams/Wabash', 'Dempster', 'Dempster', 'Dempster', 'Dempster', 'Laramie', 'Laramie', 'Laramie', 'Laramie', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'Chicago/Franklin', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'East 63rd-Cottage Grove', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Washington/Wells', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', 'Western-Cermak', "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", "Harlem-O'Hare", 'Granville', 'Granville', 'Granville', 'Granville', 'Lawrence', 'Lawrence', 'Lawrence', 'Lawrence', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Central Park', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Monroe/Dearborn', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Sedgwick', 'Medical Center', 'Medical Center', 'Medical Center', 'Medical Center', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', 'Rosemont', '18th', '18th', '18th', '18th', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'South Boulevard', 'Library', 'Library', 'Library', 'Library', 'Library', 'Francisco', 'Francisco', 'Francisco', 'Francisco', 'Thorndale', 'Thorndale', 'Thorndale', 'Thorndale', "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", "O'Hare Airport", 'Howard', 'Howard', 'Howard', 'Howard', 'Howard', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', '63rd-Dan Ryan', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Pulaski-Forest Park', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Midway Airport', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Halsted/63rd', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Pulaski-Orange', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Cicero-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', 'Harlem-Forest Park', '69th', '69th', '69th', '69th', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Cermak-Chinatown', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Rockwell', 'Logan Square', 'Logan Square', 'Logan Square', 'Logan Square', 'Polk', 'Polk', 'Polk', 'Polk', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Kedzie-Cermak', 'Linden', 'Linden', 'Linden', 'Linden', 'Linden', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Ashland-Orange', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', 'Kedzie-Lake', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', '47th-South Elevated', 'Monroe/State', 'Monroe/State', 'Monroe/State', 'Monroe/State', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', '35-Bronzeville-IIT', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'Halsted-Orange', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'King Drive', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Kedzie-Midway', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Clinton-Lake', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Garfield-Dan Ryan', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Kedzie-Brown', 'Jarvis', 'Jarvis', 'Jarvis', 'Jarvis', 'Argyle', 'Argyle', 'Argyle', 'Argyle', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Wellington', 'Fullerton', 'Fullerton', 'Fullerton', 'Fullerton', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', '47th-Dan Ryan', "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", "Addison-O'Hare", 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Central-Evanston', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', 'Austin-Lake', '43rd', '43rd', '43rd', '43rd', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Jefferson Park', 'Kimball', 'Kimball', 'Kimball', 'Kimball', 'Loyola', 'Loyola', 'Loyola', 'Loyola', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Paulina', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', 'Belmont-North Main', "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", "Montrose-O'Hare", 'LaSalle', 'LaSalle', 'LaSalle', 'LaSalle', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'Oak Park-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'California-Lake', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Bryn Mawr', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Roosevelt', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Chicago/Milwaukee', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', 'Addison-North Main', '87th', '87th', '87th', '87th', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Addison-Brown', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Chicago/State', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Irving Park-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Western-Brown', 'Harrison', 'Harrison', 'Harrison', 'Harrison', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Montrose-Brown', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Morgan-Lake', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Lake/State', 'Conservatory', 'Conservatory', 'Conservatory', 'Conservatory', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Oakton-Skokie', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place', 'Cermak-McCormick Place']

# Import the Counter object
from collections import Counter

# Create a Counter of the stations list: station_count
station_count = Counter(stations)

# Find the 5 most common elements
print(station_count.most_common(5))
# Out:
# [('Austin-Forest Park', 102), ('Sheridan', 102), ('LaSalle/Van Buren', 102), ('Cumberland', 102), ('Indiana', 102)]

# %%
from collections import defaultdict
eateries_by_park = defaultdict(list)

eatery_contact_types - defaultdict(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d2b83bbd90b6> in <module>
#       2 eateries_by_park = defaultdict(list)
#       3
# ----> 4 eatery_contact_types - defaultdict(int)
#
# NameError: name 'eatery_contact_types' is not defined

# %% [markdown]
# # Creating dictionaries of an unknown structure
# Occasionally, you'll need a structure to hold nested data, and you may not be certain that the keys will all actually exist. This can be an issue if you're trying to append items to a list for that key. You might remember the NYC data that we explored in the video. In order to solve the problem with a regular dictionary, you'll need to test that the key exists in the dictionary, and if not, add it with an empty list.
#
# You'll be working with a list of entries that contains ridership details on the Chicago transit system. You're going to solve this same type of problem with a much easier solution in the next exercise.
#
# Instructions
# 100 XP
# Create an empty dictionary called ridership.
# Iterate over entries, unpacking it into the variables date, stop, and riders.
# Check to see if the date already exists in the ridership dictionary. If it does not exist, create an empty list for the date key.
# Append a tuple consisting of stop and riders to the date key of the ridership dictionary.
# Print the ridership for '03/09/2016'.

# %%
entries= [('01/01/2015', 'Austin-Forest Park', '587'), ('01/02/2015', 'Austin-Forest Park', '1386'), ('01/03/2015', 'Austin-Forest Park', '785'), ('01/04/2015', 'Austin-Forest Park', '625'), ('01/05/2015', 'Austin-Forest Park', '1752'), ('01/06/2015', 'Austin-Forest Park', '1777'), ('01/07/2015', 'Austin-Forest Park', '1269'), ('01/08/2015', 'Austin-Forest Park', '1435'), ('01/09/2015', 'Austin-Forest Park', '1631'), ('01/10/2015', 'Austin-Forest Park', '771'), ('01/11/2015', 'Austin-Forest Park', '588'), ('01/12/2015', 'Austin-Forest Park', '2065'), ('01/13/2015', 'Austin-Forest Park', '2108'), ('01/14/2015', 'Austin-Forest Park', '2012'), ('01/15/2015', 'Austin-Forest Park', '2069'), ('01/16/2015', 'Austin-Forest Park', '2003'), ('01/17/2015', 'Austin-Forest Park', '953'), ('01/18/2015', 'Austin-Forest Park', '706'), ('01/19/2015', 'Austin-Forest Park', '1216'), ('01/20/2015', 'Austin-Forest Park', '2115'), ('01/21/2015', 'Austin-Forest Park', '2132'), ('01/22/2015', 'Austin-Forest Park', '2185'), ('01/23/2015', 'Austin-Forest Park', '2072'), ('01/24/2015', 'Austin-Forest Park', '854'), ('01/25/2015', 'Austin-Forest Park', '585'), ('01/26/2015', 'Austin-Forest Park', '2095'), ('01/27/2015', 'Austin-Forest Park', '2251'), ('01/28/2015', 'Austin-Forest Park', '2133'), ('01/29/2015', 'Austin-Forest Park', '2083'), ('01/30/2015', 'Austin-Forest Park', '2074'), ('01/31/2015', 'Austin-Forest
/2015', '51st', '872'), ('01/10/2015', '51st', '577'), ('01/11/2015', '51st', '453'), ('01/12/2015', '51st', '980'), ('01/13/2015', '51st', '990'), ('01/14/2015', '51st', '1046'), ('01/15/2015', '51st', '1005'), ('01/16/2015', '51st', '1039'), ('01/17/2015', '51st', '650'), ('01/18/2015', '51st', '490'), ('01/19/2015', '51st', '597'), ('01/20/2015', '51st', '1059'), ('01/21/2015', '51st', '1116'), ('01/22/2015', '51st', '1098'), ('01/23/2015', '51st', '994'), ('01/24/2015', '51st', '622'), ('01/25/2015', '51st', '397'), ('01/26/2015', '51st', '1004'), ('01/27/2015', '51st', '1025'), ('01/28/2015', '51st', '1063'), ('01/29/2015', '51st', '1041'), ('01/30/2015', '51st', '1136'), ('01/31/2015', '51st', '634'), ('01/01/2015', 'Dempster-Skokie', '542'), ('01/02/2015', 'Dempster-Skokie', '1562'), ('01/03/2015', 'Dempster-Skokie', '816'), ('01/04/2015', 'Dempster-Skokie', '570'), ('01/05/2015', 'Dempster-Skokie', '1767'), ('01/06/2015', 'Dempster-Skokie', '1838'), ('01/07/2015', 'Dempster-Skokie', '1317'), ('01/08/2015', 'Dempster-Skokie', '1595'), ('01/09/2015', 'Dempster-Skokie', '1620'), ('01/10/2015', 'Dempster-Skokie', '747'), ('01/11/2015', 'Dempster-Skokie', '607'), ('01/12/2015', 'Dempster-Skokie', '2198'), ('01/13/2015', 'Dempster-Skokie', '2192'), ('01/14/2015', 'Dempster-Skokie', '2153'), ('01/15/2015', 'Dempster-Skokie', '2179'), ('01/16/2015', 'Dempster-Skokie', '2103'), ('01/17/2015', 'Dempster-Skokie', '899'), ('01/18/2015', 'Dempster-Skokie', '650'), ('01/19/2015', 'Dempster-Skokie', '1582'), ('01/20/2015', 'Dempster-Skokie', '2211'), ('01/21/2015', 'Dempster-Skokie', '2149'), ('01/22/2015', 'Dempster-Skokie', '2111'), ('01/23/2015', 'Dempster-Skokie', '2038'), ('01/24/2015', 'Dempster-Skokie', '853'), ('01/25/2015', 'Dempster-Skokie', '630'), ('01/26/2015', 'Dempster-Skokie', '2171'), ('01/27/2015', 'Dempster-Skokie', '2251'), ('01/28/2015', 'Dempster-Skokie', '2108')]
       

# Create an empty dictionary: ridership
ridership = {}
from collections import defaultdict
# Iterate over the entries
for date, stop, riders in entries:
    # Check to see if date is already in the ridership dictionary
    if date not in ridership:
        # Create an empty list for any missing date
        ridership[date] =  []
    # Append the stop and riders as a tuple to the date keys list
    ridership[date].append((stop,riders))
    
# Print the ridership for '03/09/2016'
print(ridership['01/05/2015'])
# Out:
# [('Austin-Forest Park', '1752'), ('Harlem-Lake', '3287'), ('Pulaski-Lake', '1490'), ('Quincy/Wells', '8626'), ('Davis', '3524'), ("Belmont-O'Hare", '4994'), ('Jackson/Dearborn', '6929'), ('Sheridan', '5064'), ('Damen-Brown', '2386'), ('Morse', '4298'), ('35th/Archer', '2505'), ('51st', '854'), ('Dempster-Skokie', '1767')]

# %% [markdown]
# # Safely appending to a key's value list
# Often when working with dictionaries, you will need to initialize a data type before you can use it. A prime example of this is a list, which has to be initialized on each key before you can append to that list.
#
# A defaultdict allows you to define what each uninitialized key will contain. When establishing a defaultdict, you pass it the type you want it to be, such as a list, tuple, set, int, string, dictionary or any other valid type object.
#
#
# Import defaultdict from collections.
#
# Create a defaultdict with a default type of list called ridership.
#
# Iterate over the list entries, unpacking it into the variables date, stop, and riders, exactly as you did in the previous exercise.
#
# Use stop as the key of the ridership dictionary and append riders to its value.
#
# Print the first 10 items of the ridership dictionary. You can use the .items() method for this. Remember, you have to convert ridership.items() to a list before slicing.

# %%
# Import defaultdict
from collections import defaultdict

# Create a defaultdict with a default type of list: ridership
ridership = defaultdict(list)

# Iterate over the entries
for date, stop, riders in entries:
    # Use the stop as the key of ridership and append the riders to its value
    ridership[stop].append(riders)
    
# Print the first 10 items of the ridership dictionary
print(list(ridership.items())[:10])
# Out:
# [('Austin-Forest Park', ['587', '1386', '785', '625', '1752', '1777', '1269', '1435', '1631', '771', '588', '2065', '2108', '2012', '2069', '2003', '953', '706', '1216', '2115', '2132', '2185', '2072', '854', '585', '2095', '2251', '2133', '2083', '2074', '953']), ('Harlem-Lake', ['1106', '3113', '1818', '1339', '3287', '3446', '2580', '2998', '3252', '1849', '1403', '3648', '3672', '3724', '3797', '3843', '2392', '1514', '2737', '3800', '3940', '3912', '3833', '2261', '1402', '3673', '3885', '3944', '3872', '4010', '2311']), ('Pulaski-Lake', ['811', '1529', '1096', '801', '1490', '1566', '1085', '1205', '1506', '1031', '830', '1726', '1694', '1703', '1770', '1839', '1171', '858', '1276', '1884', '1806', '1786', '1828', '1335', '814', '1705', '1730', '1763', '1710', '1909', '1187']), ('Quincy/Wells', ['1117', '4645', '1217', '1009', '8626', '8642', '6678', '7906', '7828', '1236', '910', '8707', '8388', '8368', '8267', '7683', '1597', '1172', '4788', '8219', '8192', '8033', '7680', '1
# ...

# %%
from collections import OrderedDict
nyc_eatery_permits = OrderedDict()

# %% [markdown]
# # Working with OrderedDictionaries
# Recently in Python 3.6, dictionaries were made to maintain the order in which the keys were inserted; however, in all versions prior to that you need to use an OrderedDict to maintain insertion order.
#
# Let's create a dictionary of all the stop times by route and rider, then use it to find the ridership throughout the day.
#
# Instructions
# 0 XP
# Import OrderedDict from collections.
# Create an OrderedDict called ridership_date.
# Iterate over the list entries, unpacking it into date and riders.
# If a key does not exist in ridership_date for the date, set it equal to 0 (if only you could use defaultdict here!)
# Add riders to the date key of ridership_date.
# Print the first 31 records. Remember to convert the items into a list.

# %%
# Import OrderedDict from collections
from collections import OrderedDict

# Create an OrderedDict called: ridership_date
ridership_date = OrderedDict()

# Iterate over the entries
for date, riders in entries:
    # If a key does not exist in ridership_date, set it to 0
    if date not in ridership_date:
        ridership_date[date] = 0
        
    # Add riders to the date key in ridership_date
    ridership_date[date] += riders
    
# Print the first 31 records
print(list(ridership_date.items())[:31])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-de773cad2723> in <module>
#       6
#       7 # Iterate over the entries
# ----> 8 for date, riders in entries:
#       9     # If a key does not exist in ridership_date, set it to 0
#      10     if date not in ridership_date:
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# # Powerful Ordered popping
# Where OrderedDicts really shine is when you need to access the data in the dictionary in the order you added it. OrderedDict has a .popitem() method that will return items in reverse of which they were inserted. You can also pass .popitem() the last=False keyword argument and go through the items in the order of how they were added.
#
# Here, you'll use the ridership_date OrderedDict you created in the previous exercise.
#
# Instructions
# 70 XP
# Print the first key in ridership_date (Remember to make keys a list before slicing).
# Pop the first item from ridership_date and print it.
# Print the last key in ridership_date.
# Pop the last item from ridership_date and print it.

# %%
ridership_date = OrderedDict([('01/20/2015', 618377), ('01/21/2015', 619945), ('01/22/2015', 623914), ('01/23/2015', 612177), ('01/24/2015', 333440), ('01/25/2015', 226964), ('01/26/2015', 605287), ('01/27/2015', 626168), ('01/28/2015', 625531), ('01/29/2015', 622695), ('01/30/2015', 618395), ('01/31/2015', 337018), ('02/01/2015', 220964), ('02/02/2015', 462717), ('02/03/2015', 661650), ('02/04/2015', 649545), ('02/05/2015', 640499), ('02/06/2015', 630415), ('02/07/2015', 356210), ('02/08/2015', 243897), ('02/09/2015', 615678), ('02/10/2015', 634220), ('02/11/2015', 632708), ('02/12/2015', 598535), ('02/13/2015', 607818), ('02/14/2015', 308715), ('02/15/2015', 225492), ('02/16/2015', 449583), ('02/17/2015', 611935), ('02/18/2015', 580886), ('02/19/2015', 472082), ('02/20/2015', 572559), ('02/21/2015', 332841), ('02/22/2015', 244683), ('02/23/2015', 575138), ('02/24/2015', 598063), ('02/25/2015', 617616), ('02/26/2015', 619965), ('02/27/2015', 604620), ('02/28/2015', 328657), ('03/01/2015', 237326), ('03/02/2015', 587852), ('03/03/2015', 604279), ('03/04/2015', 616117), ('03/05/2015', 611076), ('03/06/2015', 601775), ('03/07/2015', 344302), ('03/08/2015', 250242), ('03/09/2015', 618273), ('03/10/2015', 630225), ('03/11/2015', 638945), ('03/12/2015', 648830), ('03/13/2015', 658139), ('03/14/2015', 542809), ('03/15/2015', 292290), ('03/16/2015', 630773), ('03/17/2015', 632302), ('03/18/2015', 633570), ('03/19/2015', 633161), ('03/20/2015', 624769), ('03/21/2015', 360547), ('03/22/2015', 247272), ('03/23/2015', 569229), ('03/24/2015', 597658), ('03/25/2015', 602932), ('03/26/2015', 604883), ('03/27/2015', 596714), ('03/28/2015', 346202), ('03/29/2015', 263081), ('03/30/2015', 604887), ('03/31/2015', 618610), ('04/01/2015', 640106), ('04/02/2015', 621918), ('04/03/2015', 556056), ('04/04/2015', 344428), ('04/05/2015', 267450), ('04/06/2015', 581195), ('04/07/2015', 593771), ('04/08/2015', 612504), ('04/09/2015', 580468), ('04/10/2015', 618124), ('04/11/2015', 378253), ('04/12/2015', 271570), ('04/13/2015', 626560), ('04/14/2015', 649901), ('04/15/2015', 650032), ('04/16/2015', 645925), ('04/17/2015', 668015), ('04/18/2
166), ('11/14/2016', 637901), ('11/15/2016', 655831), ('11/16/2016', 659192), ('11/17/2016', 667352), ('11/18/2016', 651822), ('11/19/2016', 406855), ('11/20/2016', 257262), ('11/21/2016', 623731), ('11/22/2016', 622489), ('11/23/2016', 514003), ('11/24/2016', 179471), ('11/25/2016', 338303), ('11/26/2016', 310966), ('11/27/2016', 246528), ('11/28/2016', 592973), ('11/29/2016', 634536)])

# Print the first key in ridership_date
print(list(ridership_date.keys())[0])

# Pop the first item from ridership_date and print it
print( ridership_date.popitem(last=False))

# Print the last key in ridership_date
print(list(ridership_date.keys())[-1])

# Pop the last item from ridership_date and print it
print(ridership_date.popitem(-1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8ba4e4ab299e> in <module>
# ...

# %% [markdown]
# # Creating namedtuples for storing data
# Often times when working with data, you will use a dictionary just so you can use key names to make reading the code and accessing the data easier to understand. Python has another container called a namedtuple that is a tuple, but has names for each position of the tuple. You create one by passing a name for the tuple type and a list of field names.
#
# For example, Cookie = namedtuple("Cookie", ['name', 'quantity']) will create a container, and you can create new ones of the type using Cookie('chocolate chip', 1) where you can access the name using the name attribute, and then get the quantity using the quantity attribute.
#
# In this exercise, you're going to restructure the transit data you've been working with into namedtuples for more descriptive code.
#
#
# Import namedtuple from collections.
#
# Create a namedtuple called DateDetails with a type name of DateDetails and fields of 'date', 'stop', and 'riders'.
#
# Create a list called labeled_entries.
#
# Iterate over the entries list, unpacking it into date, stop, and riders.
#
# Create a new DateDetails namedtuple instance for each entry and append it to labeled_entries.
#
# Print the first 5 items in labeled_entries. This has been done for you, so hit 'Submit Answer' to see the result!

# %%
# Import namedtuple from collections
from collections import namedtuple

# Create the namedtuple: DateDetails
DateDetails = namedtuple('DateDetails', ['date', 'stop', 'riders'])

# Create the empty list: labeled_entries
labeled_entries = []

# Iterate over the entries list
for date, stop, riders in entries:
    # Append a new DateDetails namedtuple instance for each entry to labeled_entries
    labeled_entries.append(DateDetails(date,stop,riders))
    
# Print the first 5 items in labeled_entries
print(labeled_entries[:5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8e5f9c8f34e9> in <module>
#       9
#      10 # Iterate over the entries list
# ---> 11 for date, stop, riders in entries:
#      12     # Append a new DateDetails namedtuple instance for each entry to labeled_entries
#      13     labeled_entries.append(DateDetails(date,stop,riders))
#
# NameError: name 'entries' is not defined

# %% [markdown]
# # Leveraging attributes on namedtuples
# Once you have a namedtuple, you can write more expressive code that is easier to understand. Remember, you can access the elements in the tuple by their name as an attribute. For example, you can access the date of the namedtuples in the previous exercise using the .date attribute.
#
# Here, you'll use the tuples you made in the previous exercise to see how this works.
#
# Instructions
# 0 XP
# Iterate over the first twenty items in the labeled_entries list:
# Print each item's stop.
# Print each item's date.
# Print each item's riders.

# %%
labeled_entries = [DateDetails(date='01/01/2015', stop='Austin-Forest Park', riders='587'), DateDetails(date='01/02/2015', stop='Austin-Forest Park', riders='1386'), DateDetails(date='01/03/2015', stop='Austin-Forest Park', riders='785'), DateDetails(date='01/04/2015', stop='Austin-Forest Park', riders='625'), DateDetails(date='01/05/2015', stop='Austin-Forest Park', riders='1752'), DateDetails(date='01/06/2015', stop='Austin-Forest Park', riders='1777'), DateDetails(date='01/07/2015', stop='Austin-Forest Park', riders='1269'), DateDetails(date='01/08/2015', stop='Austin-Forest Park', riders='1435'), DateDetails(date='01/09/2015', stop='Austin-Forest Park', riders='1631'), DateDetails(date='01/10/2015', stop='Austin-Forest Park', riders='771'), DateDetails(date='01/11/2015', stop='Austin-Forest Park', riders='588'), DateDetails(date='01/12/2015', stop='Austin-Forest Park', riders='2065'), DateDetails(date='01/13/2015', stop='Austin-Forest Park', riders='2108'), DateDetails(date='01/14/2015', stop='Austin-Forest Park', riders='2012'), DateDetails(date='01/15/2015', stop='Austin-Forest Park', riders='2069'), DateDetails(date='01/16/2015', stop='Austin-Forest Park', riders='2003'), DateDetails(date='01/17/2015', stop='Austin-Forest Park', riders='953'), DateDetails(date='01/18/2015', stop='Austin-Forest Park', riders='706'), DateDetails(date='01/19/2015', stop='Austin-Forest Park', riders='1216'), DateDetails(date='01/20/2015', stop='Austin-Forest Park', riders='2115'), DateDetails(date='01/21/2015', stop='Austin-Forest Park', riders='2132'), DateDetails(date='01/22/2015', stop='Austin-Forest Park', riders='2185'), DateDetails(date='01/23/2015', stop='Austin-Forest Park', riders='2072'), DateDetails(date='01/24/2015', stop='Austin-Forest Park', riders='854'), DateDetails(date='01/25/2015', stop='Austin-Forest Park', riders='585'), DateDetails(date='01/26/2015', stop='Austin-Forest Park', riders='2095'), DateDetails(date='01/27/2015', stop='Austin-Forest Park', riders='2251'), DateDetails(date='01/28/2015', stop='Austin-Forest Park', riders='2133'), DateDetails(date='01/29/2015', stop='Austin-Forest Park', riders='2083'), DateDetails(date='01/30/2015', stop='Austin-Forest Park', riders='2074')]


# Iterate over the first twenty items in labeled_entries
for item in labeled_entries[:20]:
    # Print each item's stop
    print(item.stop)

    # Print each item's date
    print(item.date)

    # Print each item's riders
    print(item.riders)
# Out:
# Austin-Forest Park
# 01/01/2015
# 587
# Austin-Forest Park
# 01/02/2015
# 1386
# Austin-Forest Park
# 01/03/2015
# 785
# Austin-Forest Park
# 01/04/2015
# 625
# Austin-Forest Park
# 01/05/2015
# 1752
# Austin-Forest Park
# 01/06/2015
# 1777
# Austin-Forest Park
# 01/07/2015
# 1269
# Austin-Forest Park
# 01/08/2015
# 1435
# Austin-Forest Park
# 01/09/2015
# 1631
# Austin-Forest Park
# 01/10/2015
# 771
# Austin-Forest Park
# 01/11/2015
# 588
# Austin-Forest Park
# 01/12/2015
# 2065
# Austin-Forest Park
# 01/13/2015
# 2108
# Austin-Forest Park
# 01/14/2015
# 2012
# Austin-Forest Park
# 01/15/2015
# 2069
# Austin-Forest Park
# 01/16/2015
# 2003
# Austin-Forest Park
# 01/17/2015
# 953
# Austin-Forest Park
# 01/18/2015
# 706
# Austin-Forest Park
# 01/19/2015
# 1216
# Austin-Forest Park
# 01/20/2015
# 2115

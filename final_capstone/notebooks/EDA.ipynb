# %%
#import libraries 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import datetime as dt
import os
sns.set_theme()

# %%
df = pd.read_csv('../../final_capstone/data/processed/netflix_data_clean.csv',index_col=0)
df = df.reset_index()

# %%
print(len(df))
df.drop('index',axis=1,inplace=True)
df.tail()
# Out:
# 13062
#                              Title                     Genre  \
# 13057       District 13: Ultimatum   Action, Crime, Thriller
# 13058               13 Going on 30  Comedy, Fantasy, Romance
# 13059                     LIFE 2.0               Documentary
# 13060                Brand New Day        Documentary, Music
# 13061  Daniel Arends: Blessuretijd                    Comedy
#
#                                                     Tags            Languages  \
# 13057  International Movies,Action Thrillers,French F...      French, English
# 13058  Romantic Comedies,Comedies,Romantic Films,Roma...  English, Portuguese
# 13059  Social & Cultural Documentaries,Biographical D...              English
# 13060  Australian Comedies,Romantic Comedies,Australi...              English
# 13061      Stand-up Comedy,International Movies,Comedies                Dutch
#
#       Series or Movie  Hidden Gem Score  \
# 13057           Movie               3.4
# ...

# %%
 df['IMDb Votes'].plot()
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Series or Movie  Hidden Gem Score  \
# 0          Series               4.3
# 1           Movie               7.0
# 2           Movie               6.4
# ...

# %%
from sklearn.preprocessing import MultiLabelBinarizer

mlb = MultiLabelBinarizer(sparse_output=True)

# %%
df['Tags_list'] = df['Tags'].str.split(',')

# %%
len(df.Tags_list)
# Out:
# 13062

# %%
df.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Series or Movie  Hidden Gem Score  \
# 0          Series               4.3
# 1           Movie               7.0
# 2           Movie               6.4
# ...

# %%
df_trash = df.join(
            pd.DataFrame.sparse.from_spmatrix(
                mlb.fit_transform(df.pop('Tags_list')),
                index=df.index,
                columns=mlb.classes_))

# %%
df_trash.columns
# Out:
# Index(['Title', 'Genre', 'Tags', 'Languages', 'Series or Movie',
#        'Hidden Gem Score', 'Country Availability', 'Runtime', 'Director',
#        'Writer',
#        ...
#        'Zombie Horror Movies', 'コメディ', 'ヒューマンドラマ', 'ラブロマンス', 'ロマンチックなヒューマンドラマ',
#        'ロマンチックコメディ', '海外コメディ', '海外ヒューマンドラマ', '海外ラブロマンス', '海外映画'],
#       dtype='object', length=1014)

# %%
df_trash.iloc[:,-998:].sum().sort_values(ascending=False)
# Out:
# Dramas                       4000
# Comedies                     3564
# Action & Adventure           1951
# International Movies         1142
# US Movies                    1138
#                              ...
# Nordic Action & Adventure       1
# Finnish TV Shows                1
# Singaporean TV Shows            1
# Silent Movies                   1
# 海外映画                            1
# Length: 998, dtype: int32

# %%
# df_trash.sum(axis=1)

# %%
# df = pd.get_dummies(df, columns=['Tags'])
# df.head()

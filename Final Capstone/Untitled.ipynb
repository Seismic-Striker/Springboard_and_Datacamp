# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('book4000k-5000k.csv')

# %%
df
# Out:
#              Id                                               Name  \
# 0       4000000                                     Top Management
# 1       4000001                          Celtic Warfare, 1595 1763
# 2       4000002                                   Playwright Power
# 3       4000009                   Selected Topics In Harmonic Maps
# 4       4000010  Foreign Exchange Intervention: Objectives And ...
# ...         ...                                                ...
# 280251  4846443                          About International Trade
# 280252  4846447  International and Global Marketing: Concepts a...
# 280253  4846448                      The Best of Vincent Mulchrone
# 280254  4846449                        Forgive Us Our Press Passes
# 280255  4846451             A Fractography Atlas Of Casting Alloys
#
#                           Authors        ISBN  Rating  PublishYear  \
# 0                 Bernard  Taylor  0582446058    0.00         1973
# ...

# %%
list(df.columns)
# Out:
# ['Id',
#  'Name',
#  'Authors',
#  'ISBN',
#  'Rating',
#  'PublishYear',
#  'PublishMonth',
#  'PublishDay',
#  'Publisher',
#  'RatingDist5',
#  'RatingDist4',
#  'RatingDist3',
#  'RatingDist2',
#  'RatingDist1',
#  'RatingDistTotal',
#  'CountsOfReview',
#  'Language',
#  'PagesNumber',
#  'Description']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280256 entries, 0 to 280255
# Data columns (total 19 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Id               280256 non-null  int64
#  1   Name             280256 non-null  object
#  2   Authors          280256 non-null  object
#  3   ISBN             279505 non-null  object
#  4   Rating           280256 non-null  float64
#  5   PublishYear      280256 non-null  int64
#  6   PublishMonth     280256 non-null  int64
#  7   PublishDay       280256 non-null  int64
#  8   Publisher        278792 non-null  object
#  9   RatingDist5      280256 non-null  object
#  10  RatingDist4      280256 non-null  object
#  11  RatingDist3      280256 non-null  object
#  12  RatingDist2      280256 non-null  object
#  13  RatingDist1      280256 non-null  object
#  14  RatingDistTotal  280256 non-null  object
#  15  CountsOfReview   280256 non-null  int64
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
df = pd.read_excel (r'GVP_Volcano_List_Holocene.xlsx', sheet_name='Holocene Volcano List',header=1)

# %%
df.shape
df.columns
df.dtypes
# Out:
# Volcano Number            int64
# Volcano Name             object
# Country                  object
# Primary Volcano Type     object
# Activity Evidence        object
# Last Known Eruption      object
# Region                   object
# Subregion                object
# Latitude                float64
# Longitude               float64
# Elevation (m)             int64
# Dominant Rock Type       object
# Tectonic Setting         object
# dtype: object

# %%
df.head()
# Out:
#    Volcano Number               Volcano Name  Country Primary Volcano Type  \
# 0          210010  West Eifel Volcanic Field  Germany              Maar(s)
# 1          210020            Chaine des Puys   France         Lava dome(s)
# 2          210030        Olot Volcanic Field    Spain  Pyroclastic cone(s)
# 3          210040   Calatrava Volcanic Field    Spain  Pyroclastic cone(s)
# 4          211003                    Vulsini    Italy              Caldera
#
#    Activity Evidence Last Known Eruption                          Region  \
# 0     Eruption Dated            8300 BCE  Mediterranean and Western Asia
# 1     Eruption Dated            4040 BCE  Mediterranean and Western Asia
# 2  Evidence Credible             Unknown  Mediterranean and Western Asia
# 3     Eruption Dated            3600 BCE  Mediterranean and Western Asia
# 4  Eruption Observed             104 BCE  Mediterranean and Western Asia
#
#         Subregion  Latitude  Longitude  Elevation (m)  \
# ...

# %%
#Here we are going to turn Last Known Eruption into date (years) and unknowns

df['Last Known Eruption']

#looks for values containing BCE    
BCE = [s for s in df['Last Known Eruption'] if "BCE" in s]
#removes BCE string
BCE = [x.strip(' BCE') for x in BCE]
#defines them as integers
BCE = list(map(int, BCE))
#add minus sign to BCE years
BCE = [ -x for x in BCE]


CE = [s for s in df["Last Known Eruption"] if " CE" in s]
CE = [x.strip(' CE') for x in CE]
CE = list(map(int, CE))

#merges the BCE and the CE integers to one list
mergedlist = BCE + CE

#list(filter(lambda k: 'BCE' in k, df['Last Known Eruption']))
#plot the list
sns.displot(mergedlist)
plt.xlabel("Year")
plt.title('How Long Ago Volcanos Have Erupted by Count')
# Out:
# Text(0.5, 1.0, 'How Long Ago Volcanos Have Erupted by Count')

# %%
tectonic_settings = df['Tectonic Setting'].value_counts()
tectonic_settings.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Tectonic Setting'>

# %%
Volc_type = df['Primary Volcano Type'].value_counts()
Volc_type.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Primary Volcano Type'>

# %%
country =df['Country'].value_counts()
country.head(15).plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
countries = df.groupby('Country')
countries = countries.sort

# %%
countries.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-ba1cd36c91e5> in <module>
# ----> 1 countries.head()
#       2
#       3
#       4
#
# AttributeError: 'bool' object has no attribute 'head'
